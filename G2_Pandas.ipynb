# %% [markdown]
# <a href="https://colab.research.google.com/github/nikolooo/Google-Colab/blob/main/G2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = "http://bit.ly/w-data"
date = pd.read_csv (url)
print("Data Loaded Successfully")
# Out:
# Data Loaded Successfully

# %%
data = pd.read_csv (url, index_col = 'Hours')
row_val = data.loc [3.2]
print (row_val)
# Out:
# Scores    27
# Name: 3.2, dtype: int64

# %%
data.head(4)
# Out:
#        Scores
# Hours
# 2.5        21
# 5.1        47
# 3.2        27
# 8.5        75

# %%
data.tail()
# Out:
#        Scores
# Hours
# 2.7        30
# 4.8        54
# 3.8        35
# 6.9        76
# 7.8        86

# %%
data.describe()
# Out:
#           Scores
# count  25.000000
# mean   51.480000
# std    25.286887
# min    17.000000
# 25%    30.000000
# 50%    47.000000
# 75%    75.000000
# max    95.000000

# %%
s = pd.Series(data['Hours'])
print(s)

# %%
s = pd.Series(data['Scores'])
print(s)
# Out:
# Hours
# 2.5    21
# 5.1    47
# 3.2    27
# 8.5    75
# 3.5    30
# 1.5    20
# 9.2    88
# 5.5    60
# 8.3    81
# 2.7    25
# 7.7    85
# 5.9    62
# 4.5    41
# 3.3    42
# 1.1    17
# 8.9    95
# 2.5    30
# 1.9    24
# 6.1    67
# 7.4    69
# 2.7    30
# 4.8    54
# 3.8    35
# 6.9    76
# 7.8    86
# Name: Scores, dtype: int64

# %%
s.index
# Out:
# Float64Index([2.5, 5.1, 3.2, 8.5, 3.5, 1.5, 9.2, 5.5, 8.3, 2.7, 7.7, 5.9, 4.5,
#               3.3, 1.1, 8.9, 2.5, 1.9, 6.1, 7.4, 2.7, 4.8, 3.8, 6.9, 7.8],
#              dtype='float64', name='Hours')

# %%
s.values
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86])

# %%
s[2]

# %%
type(data['Hours'])

# %%
print(data)
# Out:
#        Scores
# Hours
# 2.5        21
# 5.1        47
# 3.2        27
# 8.5        75
# 3.5        30
# 1.5        20
# 9.2        88
# 5.5        60
# 8.3        81
# 2.7        25
# 7.7        85
# 5.9        62
# 4.5        41
# 3.3        42
# 1.1        17
# 8.9        95
# 2.5        30
# 1.9        24
# 6.1        67
# 7.4        69
# 2.7        30
# 4.8        54
# 3.8        35
# 6.9        76
# 7.8        86

# %%
data.columns
# Out:
# Index(['Scores'], dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# Out:
# Scores    int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 25 entries, 2.5 to 7.8
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Scores  25 non-null     int64
# dtypes: int64(1)
# memory usage: 956.0 bytes

# %%
data.values
# Out:
# array([[21],
#        [47],
#        [27],
#        [75],
#        [30],
#        [20],
#        [88],
#        [60],
#        [81],
#        [25],
#        [85],
#        [62],
#        [41],
#        [42],
#        [17],
#        [95],
#        [30],
#        [24],
#        [67],
#        [69],
#        [30],
#        [54],
#        [35],
#        [76],
#        [86]])

# %%
data_index = data.set_index("Scores")
print(data_index)
# Out:
# Empty DataFrame
# Columns: []
# Index: [21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30, 24, 67, 69, 30, 54, 35, 76, 86]

# %% [markdown]
# ---
#
#
# ## **Basic Operations**
#
# ---

# %%
hours_studied = pd.Series(data['Hours'])
print(hours_studied*5)

# %%
hours_studied.mean()

# %%
data['Scores'].min()
# Out:
# 17

# %%
data['Scores'].median()
# Out:
# 47.0

# %%
data.median()
# Out:
# Scores    47.0
# dtype: float64

# %%
data['weekly_hours'] = hours_studied*5
print(data)

# %%
data.sort_values('Scores',ascending = True)
# Out:
#        Scores
# Hours
# 1.1        17
# 1.5        20
# 2.5        21
# 1.9        24
# 2.7        25
# 3.2        27
# 2.7        30
# 3.5        30
# 2.5        30
# 3.8        35
# 4.5        41
# 3.3        42
# 5.1        47
# 4.8        54
# 5.5        60
# 5.9        62
# 6.1        67
# 7.4        69
# 8.5        75
# 6.9        76
# 8.3        81
# 7.7        85
# 7.8        86
# 9.2        88
# 8.9        95

# %%
data.sort_values('Scores',ascending = False)
# Out:
#        Scores
# Hours
# 8.9        95
# 9.2        88
# 7.8        86
# 7.7        85
# 8.3        81
# 6.9        76
# 8.5        75
# 7.4        69
# 6.1        67
# 5.9        62
# 5.5        60
# 4.8        54
# 5.1        47
# 3.3        42
# 4.5        41
# 3.8        35
# 2.5        30
# 2.7        30
# 3.5        30
# 3.2        27
# 2.7        25
# 1.9        24
# 2.5        21
# 1.5        20
# 1.1        17

# %%
data.sort_values(by=['Scores','Hours'],ascending = False)
# Out:
#        Scores
# Hours
# 8.9        95
# 9.2        88
# 7.8        86
# 7.7        85
# 8.3        81
# 6.9        76
# 8.5        75
# 7.4        69
# 6.1        67
# 5.9        62
# 5.5        60
# 4.8        54
# 5.1        47
# 3.3        42
# 4.5        41
# 3.8        35
# 3.5        30
# 2.7        30
# 2.5        30
# 3.2        27
# 2.7        25
# 1.9        24
# 2.5        21
# 1.5        20
# 1.1        17

# %%
data.plot()

# %%
data['Scores'].plot(kind='bar')
# Out:
# <Axes: xlabel='Hours'>

# %%
data.to_csv('scores.csv')
